# %% [markdown]
# # Claims Denial Prediction Walkthrough
#
# Use the scripts in `src/` to generate data, train the model, and score claims.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/claims_denial_synthetic.csv')
df.head()
